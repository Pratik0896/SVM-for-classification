# %% [markdown]
# Training a SVM model to classify human cells in benign or malignant.
# dataset has class attribute with value=2 (benign) and value=4 (malignant)

# %%
#import libraries.
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
#import dataset.
data = pd.read_csv('cell_samples.csv')
data.head()
# Out:
#         ID  Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  \
# 0  1000025      5         1          1        1            2       1
# 1  1002945      5         4          4        5            7      10
# 2  1015425      3         1          1        1            2       2
# 3  1016277      6         8          8        1            3       4
# 4  1017023      4         1          1        3            2       1
#
#    BlandChrom  NormNucl  Mit  Class
# 0           3         1    1      2
# 1           3         2    1      2
# 2           3         1    1      2
# 3           3         7    1      2
# 4           3         1    1      2

# %%
#check data in target set (class attribute of dataset).
data[['Class']]
# Out:
#      Class
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
# ..     ...
# 694      2
# 695      2
# 696      4
# 697      4
# 698      4
#
# [699 rows x 1 columns]

# %%
list(data['Class'].unique())
# Out:
# [2, 4]

# %%
#check for basic statistics.
data.describe()
# Out:
#                  ID       Clump    UnifSize   UnifShape     MargAdh  \
# count  6.990000e+02  699.000000  699.000000  699.000000  699.000000
# mean   1.071704e+06    4.417740    3.134478    3.207439    2.806867
# std    6.170957e+05    2.815741    3.051459    2.971913    2.855379
# min    6.163400e+04    1.000000    1.000000    1.000000    1.000000
# 25%    8.706885e+05    2.000000    1.000000    1.000000    1.000000
# 50%    1.171710e+06    4.000000    1.000000    1.000000    1.000000
# 75%    1.238298e+06    6.000000    5.000000    5.000000    4.000000
# max    1.345435e+07   10.000000   10.000000   10.000000   10.000000
#
#        SingEpiSize  BlandChrom    NormNucl         Mit       Class
# count   699.000000  699.000000  699.000000  699.000000  699.000000
# mean      3.216023    3.437768    2.866953    1.589413    2.689557
# std       2.214300    2.438364    3.053634    1.715078    0.951273
# min       1.000000    1.000000    1.000000    1.000000    2.000000
# ...

# %%
#verifying datatypes
data.dtypes
# Out:
# ID              int64
# Clump           int64
# UnifSize        int64
# UnifShape       int64
# MargAdh         int64
# SingEpiSize     int64
# BareNuc        object
# BlandChrom      int64
# NormNucl        int64
# Mit             int64
# Class           int64
# dtype: object

# %%
#Machine learning model cannot process object type data. therefore converting object type data into Numeric format.
data = data[pd.to_numeric(data['BareNuc'],errors='coerce').notnull()]
data['BareNuc'] = data['BareNuc'].astype('int64')

# %%
data.dtypes
# Out:
# ID             int64
# Clump          int64
# UnifSize       int64
# UnifShape      int64
# MargAdh        int64
# SingEpiSize    int64
# BareNuc        int64
# BlandChrom     int64
# NormNucl       int64
# Mit            int64
# Class          int64
# dtype: object

# %%
#seleccting feature set and target set from the pre-processed dataset.
feature_set = data.iloc[:,1:10]
feature_set
# Out:
#      Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BareNuc  BlandChrom  \
# 0        5         1          1        1            2        1           3
# 1        5         4          4        5            7       10           3
# 2        3         1          1        1            2        2           3
# 3        6         8          8        1            3        4           3
# 4        4         1          1        3            2        1           3
# ..     ...       ...        ...      ...          ...      ...         ...
# 694      3         1          1        1            3        2           1
# 695      2         1          1        1            2        1           1
# 696      5        10         10        3            7        3           8
# 697      4         8          6        4            3        4          10
# 698      4         8          8        5            4        5          10
#
#      NormNucl  Mit
# 0           1    1
# 1           2    1
# ...

# %%
#selecting target set.
target_set = data.iloc[:,-1]
target_set
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 694    2
# 695    2
# 696    4
# 697    4
# 698    4
# Name: Class, Length: 683, dtype: int64

# %%
#splitting into training and testing sets.
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(feature_set, target_set, test_size=0.2, random_state = 0)

# %%
#creating SVM model
from sklearn import svm
model = svm.SVC(kernel='rbf')
model.fit(train_x, train_y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#predicting the class variable(target_set).
y_pred = model.predict(test_x)     
y_pred
# Out:
# array([2, 2, 4, 4, 2, 2, 2, 4, 2, 2, 4, 2, 4, 2, 2, 4, 4, 4, 4, 2, 2, 2,
#        4, 2, 4, 4, 2, 2, 2, 4, 2, 4, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 2,
#        2, 2, 2, 4, 2, 2, 4, 2, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 2, 4, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 4, 2, 4,
#        4, 2, 4, 2, 4, 4, 2, 4, 4, 4, 4, 2, 2, 2, 4, 4, 2, 2, 4, 4, 2, 2,
#        4, 2, 2, 4, 2, 2, 2, 4, 2, 2, 2, 4, 2, 2, 4, 4, 2, 4, 2, 4, 2, 2,
#        4, 2, 2, 4, 2], dtype=int64)

# %%
#find accuracy using f1 score.
from sklearn.metrics import f1_score
accuracy = f1_score(test_y, y_pred, average='weighted')

# %%
print(accuracy)
# Out:
# 0.9637150064588158
